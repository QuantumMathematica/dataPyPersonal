# %%
# Import the required libraries
import seaborn as sns
from matplotlib import cm
import numpy as np
import pandas as pd
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\L00698076\\Documents\\GitHub\\dataPyPersonal\\scripts'

# %%
# Load the dataset
data = pd.read_csv("..\\data\\extracted\\NFL\\NFL.csv")
data.head()
list(data.columns)
# Out:
# ['Age',
#  'Birth Place',
#  'Birthday',
#  'College',
#  'Current Status',
#  'Current Team',
#  'Experience',
#  'Height (inches)',
#  'High School',
#  'High School Location',
#  'Name',
#  'Number',
#  'Player Id',
#  'Position',
#  'Weight (lbs)',
#  'Years Played']

# %% [markdown]
# #### Load the dataset
# data = pd.read_csv("C:\Users\L00698076\Documents\GitHub\dataPyPersonal\data\extracted\NFL.csv")
# data.head()
# list(data.columns)

# %%
# Filtering and Selecting
ageFilterValue = 20
ageFilter = data["Age"] > ageFilterValue
aboveAge = data[ageFilter]
len(aboveAge)
# Out:
# 13493

# %%
aboveAge.head(10)
# Out:
#      Age       Birth Place    Birthday              College Current Status  \
# 2   56.0       Temple , TX   9/11/1960       Louisiana Tech        Retired
# 3   30.0  New Orleans , LA   9/30/1986                  LSU        Retired
# 4   25.0      Detroit , MI   3/31/1992     Central Michigan         Active
# 7   22.0      Navarre , FL   1/31/1995              Clemson         Active
# 9   98.0     Alverton , PA   2/23/1919             Duquesne        Retired
# 11  56.0        Alton , IL   2/10/1961  Southern University        Retired
# 12  33.0               NaN   12/4/1983          Boise State        Retired
# 13  27.0  Little Rock , AR  11/22/1989             Arkansas        Retired
# 14  73.0    St. Louis , MO   12/8/1943             Missouri        Retired
# 15  74.0    Barberton , OH    9/1/1942          Florida A&M        Retired
#
#            Current Team  Experience  Height (inches)     High School  \
# 2                   NaN    1 Season             74.0             NaN
# 3                   NaN   5 Seasons             73.0             NaN
# 4   Pittsburgh Steelers  3rd season             77.0  Clintondale HS
# 7         New York Jets      Rookie             77.0      Navarre HS
# 9                   NaN    1 Season             70.0             NaN
# 11                  NaN    1 Season             69.0             NaN
# 12                  NaN    1 Season             74.0             NaN
# 13                  NaN   3 Seasons             71.0             NaN
# 14                  NaN   8 Seasons             73.0             NaN
# 15                  NaN   3 Seasons             73.0             NaN
#
#            High School Location              Name  Number  \
# 2                           NaN     Fowler, Bobby     NaN
# 3                           NaN    Johnson, Quinn     NaN
# 4   Clinton Twp.,Macomb Co., MI      Walton, L.T.    96.0
# 7                            FL   Leggett, Jordan     NaN
# 9                           NaN     Gonda, George     NaN
# 11                          NaN     Raglin, Floyd     NaN
# 12                          NaN  Zabransky, Jared     NaN
# 13                          NaN        Adams, Joe     NaN
# 14                          NaN         Otto, Gus     NaN
# 15                          NaN      Thomas, Gene     NaN
#
#                  Player Id Position  Weight (lbs) Years Played
# 2      bobbyfowler/2514295      NaN         230.0  1985 - 1985
# 3       quinnjohnson/79593      NaN         255.0  2009 - 2013
# 4       l.t.walton/2552444       DE         305.0          NaN
# 7    jordanleggett/2557885       TE         250.0          NaN
# 9      georgegonda/2515030      NaN         175.0  1942 - 1942
# 11     floydraglin/2523695      NaN         180.0  1987 - 1987
# 12  jaredzabransky/2495791      NaN         219.0  2007 - 2007
# 13        joeadams/2532782      NaN         185.0  2012 - 2014
# 14         gusotto/2522592      NaN         220.0  1965 - 1972
# 15      genethomas/2527241      NaN         210.0  1966 - 1968

# %%
data["Current Status"].unique()
activeFilter = data["Current Status"] == "Active"
aboveAndActive = data[ageFilter & activeFilter]
len(aboveAndActive)
# Out:
# 2731

# %%
aboveAndActive.head(10)
# Out:
#      Age       Birth Place    Birthday           College Current Status  \
# 4   25.0      Detroit , MI   3/31/1992  Central Michigan         Active
# 7   22.0      Navarre , FL   1/31/1995           Clemson         Active
# 17  25.0               NaN   3/11/1992        Pittsburgh         Active
# 35  29.0       Dayton , OH    4/1/1988        Ohio State         Active
# 37  26.0        Rodeo , CA   7/28/1990           Ohio U.         Active
# 39  29.0   Fort Myers , FL  11/30/1987     South Florida         Active
# 45  24.0               NaN    5/5/1993             Akron         Active
# 52  24.0  Kansas City , MO   1/15/1993   Pittsburg State         Active
# 63  27.0     Stockton , CA    1/1/1990           Montana         Active
# 64  30.0       Casper , WY  11/19/1986              Utah         Active
#
#            Current Team  Experience  Height (inches)  \
# 4   Pittsburgh Steelers  3rd season             77.0
# 7         New York Jets      Rookie             77.0
# 17  Washington Redskins  1st season             74.0
# 35    Carolina Panthers  8th season             71.0
# 37      Oakland Raiders  4th season             72.0
# 39       Miami Dolphins  8th season             72.0
# 45  Washington Redskins  1st season             75.0
# 52   Kansas City Chiefs  2nd season             74.0
# 63     Los Angeles Rams  6th season             74.0
# 64  San Francisco 49ers  8th season             76.0
#
#                      High School         High School Location  \
# 4                 Clintondale HS  Clinton Twp.,Macomb Co., MI
# 7                     Navarre HS                           FL
# 17                           NaN                          NaN
# 35                  Northmont HS                  Clayton, OH
# 37                De La Salle HS                  Concord, CA
# 39                 Cape Coral HS                           FL
# 45                           NaN                          NaN
# 52  Hogan Preparatory Academy HS              Kansas City, MO
# 63                     Edison HS                 Stockton, CA
# 64                  Hillcrest HS                  Midvale, UT
#
#                  Name  Number                Player Id Position  Weight (lbs)  \
# 4        Walton, L.T.    96.0       l.t.walton/2552444       DE         305.0
# 7     Leggett, Jordan     NaN    jordanleggett/2557885       TE         250.0
# 17   Garner, Manasseh     NaN   manassehgarner/2553801       TE         220.0
# 35      Coleman, Kurt    20.0       kurtcoleman/494261       SS         200.0
# 37       Carrie, T.J.    38.0       t.j.carrie/2550164       SS         205.0
# 39        Allen, Nate     NaN        nateallen/2508043       DB         210.0
# 45   Williams, Isaiah    63.0   isaiahwilliams/2557450       OT         295.0
# 52    Bausby, DeVante     NaN    devantebausby/2553790       CB         190.0
# 63  Johnson, Trumaine    22.0  trumainejohnson/2532877       CB         208.0
# 64      Beadles, Zane    68.0       zanebeadles/496980        G         305.0
#
#    Years Played
# 4           NaN
# 7           NaN
# 17          NaN
# 35          NaN
# 37          NaN
# 39          NaN
# 45          NaN
# 52          NaN
# 63          NaN
# 64          NaN

# %%
# Plotting
frequencies = aboveAndActive["Position"].value_counts()
frequencies.plot.bar(
    title=(
        "Active players above " +
        str(ageFilterValue) +
        " and grouped by position"
    )
)

# %%
# Plotting
frequencies = aboveAndActive["Position"].value_counts()
frequencies.plot.bar(
    title=(
        f"Active players above {ageFilterValue} and grouped by position"
    )
)

# %%
# Plotting with style
color = cm.inferno_r(np.linspace(.4, .8, 30))
frequencies.plot(
    kind="bar",
    title=(
        f"Active players above {ageFilterValue} and grouped by position"
    ),
    color=color
)
plt.savefig('../images/nflBar.png', dpi=500)

# %%
# Scatter plot
sns.lmplot(
    x="Height (inches)", y="Weight (lbs)", data=aboveAndActive,
    aspect=1.5, fit_reg=False, hue='Position', legend=True,
    palette=sns.color_palette("hls", len(aboveAndActive["Position"].unique()))
)
plt.savefig('../images/nflScatter.png', dpi=500)
